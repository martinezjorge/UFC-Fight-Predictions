# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
ufc_master = pd.read_csv('ufc-master.csv')
ufc_master.head()
# Out:
#              R_fighter         B_fighter  R_odds  B_odds       R_ev  \
# 0  Deiveson Figueiredo  Joseph Benavidez    -225     180  44.444444
# 1      Jack Hermansson   Kelvin Gastelum    -112    -112  89.285714
# 2        Marc Diakiese     Rafael Fiziev    -167     135  59.880240
# 3        Ariane Lipski    Luana Carolina    -125     100  80.000000
# 4    Alexandre Pantoja     Askar Askarov    -210     165  47.619048
#
#          B_ev       date                                    location  \
# 0  180.000000  7/18/2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 1   89.285714  7/18/2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 2  135.000000  7/18/2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 3  100.000000  7/18/2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 4  165.000000  7/18/2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
#
#                 country Winner  ...  B_Featherweight_rank B_Bantamweight_rank  \
# ...

# %%
most_recent_event = pd.read_csv('most-recent-event.csv')
most_recent_event
# Out:
#               R_fighter         B_fighter  R_odds  B_odds        R_ev  \
# 0   Deiveson Figueiredo  Joseph Benavidez    -225     180   44.444444
# 1       Jack Hermansson   Kelvin Gastelum    -112    -112   89.285714
# 2         Marc Diakiese     Rafael Fiziev    -167     135   59.880240
# 3         Ariane Lipski    Luana Carolina    -125     100   80.000000
# 4     Alexandre Pantoja     Askar Askarov    -210     165   47.619048
# 5         Roman Dolidze  Khadis Ibragimov    -167     135   59.880240
# 6          Grant Dawson      Nad Narimani    -250     195   40.000000
# 7             Joe Duffy      Joel Alvarez    -335     250   29.850746
# 8           Brett Johns    Montel Jackson     170    -215  170.000000
# 9        Malcolm Gordon       Amir Albazi     135    -167  135.000000
# 10           Davi Ramos   Arman Tsarukyan     160    -200  160.000000
# 11        Carlos Felipe    Serghei Spivac     140    -177  140.000000
#
# ...

# %%
upcoming_event = pd.read_csv('upcoming-event.csv')
upcoming_event
# Out:
#              R_fighter              B_fighter  R_odds  B_odds        R_ev  \
# 0     Robert Whittaker            Darren Till    -120    -105   83.333333
# 1         Mauricio Rua       Rogerio Nogueira    -200     155   50.000000
# 2      Fabricio Werdum   Alexander Gustafsson     275    -360  275.000000
# 3        Carla Esparza       Marina Rodriguez     134    -167  134.000000
# 4           Paul Craig  Gadzhimurad Antigulov    -134     110   74.626866
# 5        Alex Oliveira          Peter Sobotta    -177     140   56.497175
# 6      Khamzat Chimaev             Rhys McKee   -1000     600   10.000000
# 7   Francisco Trinaldo            Jai Herbert    -177     140   56.497175
# 8        Nicolas Dalby           Jesse Ronson    -265     205   37.735849
# 9         Tom Aspinall           Jake Collier    -225     175   44.444444
# 10       Movsar Evloev            Mike Grundy    -215     170   46.511628
# 11        Tanner Boser         Raphael Pessoa    -278     215   35.971223
# ...

# %%
task_template = pd.read_csv('task-dummy.csv')
task_template
# Out:
#              R_fighter              B_fighter  R_prob  B_prob
# 0     Robert Whittaker            Darren Till     0.5     0.5
# 1         Mauricio Rua       Rogerio Nogueira     0.5     0.5
# 2      Fabricio Werdum   Alexander Gustafsson     0.5     0.5
# 3        Carla Esparza       Marina Rodriguez     0.5     0.5
# 4           Paul Craig  Gadzhimurad Antigulov     0.5     0.5
# 5        Alex Oliveira          Peter Sobotta     0.5     0.5
# 6      Khamzat Chimaev             Rhys McKee     0.5     0.5
# 7   Francisco Trinaldo            Jai Herbert     0.5     0.5
# 8        Nicolas Dalby           Jesse Ronson     0.5     0.5
# 9         Tom Aspinall           Jake Collier     0.5     0.5
# 10       Movsar Evloev            Mike Grundy     0.5     0.5
# 11        Tanner Boser         Raphael Pessoa     0.5     0.5
# 12       Bethe Correia         Pannie Kianzad     0.5     0.5
# 13       Ramazan Emeev          Niklas Stolze     0.5     0.5
# ...

# %%
r_fighters = task_template.R_fighter.tolist()
b_fighters = task_template.B_fighter.tolist()

# %%
print(r_fighters), print(b_fighters)
# Out:
# ['Robert Whittaker', 'Mauricio Rua', 'Fabricio Werdum', 'Carla Esparza', 'Paul Craig', 'Alex Oliveira', 'Khamzat Chimaev', 'Francisco Trinaldo', 'Nicolas Dalby', 'Tom Aspinall', 'Movsar Evloev', 'Tanner Boser', 'Bethe Correia', 'Ramazan Emeev', 'Nathaniel Wood']
# ['Darren Till', 'Rogerio Nogueira', 'Alexander Gustafsson', 'Marina Rodriguez', 'Gadzhimurad Antigulov', 'Peter Sobotta', 'Rhys McKee', 'Jai Herbert', 'Jesse Ronson', 'Jake Collier', 'Mike Grundy', 'Raphael Pessoa', 'Pannie Kianzad', 'Niklas Stolze', 'John Castaneda']
# (None, None)

# %%
for fighter in r_fighters:
    fights = ufc_masterprint(fighter)
# Out:
# Robert Whittaker
# Mauricio Rua
# Fabricio Werdum
# Carla Esparza
# Paul Craig
# Alex Oliveira
# Khamzat Chimaev
# Francisco Trinaldo
# Nicolas Dalby
# Tom Aspinall
# Movsar Evloev
# Tanner Boser
# Bethe Correia
# Ramazan Emeev
# Nathaniel Wood

# %%
fights_whittaker = ufc_master[ufc_master['R_fighter']==r_fighters[0]]

# %%
fights_whittaker
# Out:
#              R_fighter         B_fighter  R_odds  B_odds        R_ev  \
# 360   Robert Whittaker   Israel Adesanya     110    -130  110.000000
# 998   Robert Whittaker       Yoel Romero    -275     235   36.363636
# 1695  Robert Whittaker     Derek Brunson     100    -120  100.000000
# 1988  Robert Whittaker      Rafael Natal    -325     265   30.769231
# 2664  Robert Whittaker      Clint Hester     170    -185  170.000000
# 2853  Robert Whittaker       Mike Rhodes    -250     230   40.000000
# 3015  Robert Whittaker  Stephen Thompson     120    -130  120.000000
# 3478  Robert Whittaker     Bradley Scott    -235     215   42.553191
#
#             B_ev        date                            location  \
# 360    76.923077   10/5/2019      Melbourne, Victoria, Australia
# 998   235.000000    6/9/2018              Chicago, Illinois, USA
# 1695   83.333333  11/26/2016      Melbourne, Victoria, Australia
# 1988  265.000000   4/23/2016              Las Vegas, Nevada, USA
# ...
